# %%
# !pip install deepface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 26.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 7.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.4/84.4 kB 8.4 MB/s eta 0:00:00
# ...
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117029 sha256=095b77a72061069c79129456a1060194046b29b924e266aa98c469e37d5559d2
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
# Successfully built fire
# ...

# %%
# !pip install opencv-python

# %%
# !pip install face_recognition
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566170 sha256=bc013739c9590be0dfc9454ed75175fdaa1123a0952085aaa5ff272b4c718c8c
#   Stored in directory: /root/.cache/pip/wheels/7a/eb/cf/e9eced74122b679557f597bb7c8e4c739cfcac526db1fd523d
# Successfully built face-recognition-models
# ...

# %%
# !pip install pillow

# %%
# !pip install pandas

# %%
# !pip install numpy

# %%
actions=['age','gender','emotion','race']

# %%
import pandas
import cv2
import numpy
from deepface import DeepFace
# Out:
# 24-04-18 06:18:39 - Directory /root/.deepface created
# 24-04-18 06:18:39 - Directory /root/.deepface/weights created

# %%
img_path='Tushar.png'

# %%
result=DeepFace.analyze(img_path,actions)
# Out:
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# 24-04-18 06:21:16 - age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
#
#   0%|          | 0.00/539M [00:00<?, ?B/s]
#   0%|          | 1.05M/539M [00:00<01:10, 7.67MB/s]
#   0%|          | 2.62M/539M [00:00<00:51, 10.4MB/s]
#   1%|          | 4.72M/539M [00:00<00:39, 13.6MB/s]
#   1%|▏         | 7.34M/539M [00:00<00:30, 17.6MB/s]
#   2%|▏         | 11.0M/539M [00:00<00:22, 23.2MB/s]
#   3%|▎         | 15.7M/539M [00:00<00:17, 30.6MB/s]
#   4%|▍         | 22.0M/539M [00:00<00:12, 40.4MB/s]
#   6%|▌         | 30.4M/539M [00:00<00:09, 53.1MB/s]
#   8%|▊         | 41.9M/539M [00:01<00:06, 71.5MB/s]
#  11%|█         | 57.7M/539M [00:01<00:04, 96.6MB/s]
#  14%|█▍        | 75.0M/539M [00:01<00:03, 119MB/s]
#  17%|█▋        | 93.8M/539M [00:01<00:03, 138MB/s]
# ...

# %%
# !pip install matplotlib

# %%
img_path_robert='robert.jpg'

# %%
result_robert=DeepFace.analyze(img_path_robert,actions)
# Out:
# Action: race: 100%|██████████| 4/4 [00:01<00:00,  2.21it/s]

# %%
import matplotlib.pyplot as plt

# %%
img_robert=plt.imread('robert.jpg')

# %%
img_robert
# Out:
# array([[[219, 218, 200],
#         [219, 218, 200],
#         [218, 217, 199],
#         ...,
#         [221, 218, 201],
#         [221, 218, 201],
#         [221, 218, 201]],
#
#        [[219, 218, 200],
#         [218, 217, 199],
#         [218, 217, 199],
#         ...,
#         [221, 218, 201],
#         [221, 218, 201],
#         [221, 218, 201]],
#
#        [[218, 217, 199],
#         [218, 217, 199],
#         [218, 217, 199],
#         ...,
#         [221, 218, 201],
#         [221, 218, 201],
#         [221, 218, 201]],
#
#        ...,
#
#        [[226, 224, 211],
#         [228, 226, 213],
#         [231, 229, 216],
#         ...,
#         [231, 230, 212],
#         [229, 228, 210],
#         [229, 228, 210]],
#
#        [[225, 223, 210],
#         [228, 226, 213],
#         [231, 229, 216],
#         ...,
#         [230, 229, 211],
#         [228, 227, 209],
#         [228, 227, 209]],
#
#        [[228, 226, 213],
#         [229, 227, 214],
#         [230, 228, 215],
# ...

# %%
result_robert
# Out:
# [{'age': 48,
#   'region': {'x': 290,
#    'y': 126,
#    'w': 250,
#    'h': 250,
#    'left_eye': (442, 213),
#    'right_eye': (366, 225)},
#   'face_confidence': 0.95,
#   'gender': {'Woman': 0.0025450357497902587, 'Man': 99.99746084213257},
#   'dominant_gender': 'Man',
#   'emotion': {'angry': 5.524920299649239,
#    'disgust': 1.4543296512274477e-12,
#    'fear': 0.06397758261300623,
#    'happy': 0.005539040284929797,
#    'sad': 0.7427913136780262,
#    'surprise': 2.495934836588276e-06,
#    'neutral': 93.66276860237122},
#   'dominant_emotion': 'neutral',
#   'race': {'asian': 7.690352946519852,
#    'indian': 11.251010745763779,
#    'black': 2.390517480671406,
#    'white': 25.843891501426697,
#    'middle eastern': 21.94712460041046,
#    'latino hispanic': 30.87710440158844},
#   'dominant_race': 'latino hispanic'}]

# %%
img_path_bhelpuria="bhelpuria.webp"
image_bhelpuria=plt.imread("bhelpuria.webp")

# %%
result_bhelpuria=DeepFace.analyze(img_path_bhelpuria,actions)
# Out:
# Action: race: 100%|██████████| 4/4 [00:03<00:00,  1.30it/s]

# %%
result_bhelpuria
# Out:
# [{'age': 30,
#   'region': {'x': 697,
#    'y': 191,
#    'w': 473,
#    'h': 473,
#    'left_eye': (1000, 355),
#    'right_eye': (843, 374)},
#   'face_confidence': 0.93,
#   'gender': {'Woman': 0.03013357345480472, 'Man': 99.96986389160156},
#   'dominant_gender': 'Man',
#   'emotion': {'angry': 15.727609395980835,
#    'disgust': 1.5321903468201725e-08,
#    'fear': 1.5747839584946632,
#    'happy': 0.06942427135072649,
#    'sad': 24.423684179782867,
#    'surprise': 0.0002042393816736876,
#    'neutral': 58.20428729057312},
#   'dominant_emotion': 'neutral',
#   'race': {'asian': 0.005832823792170475,
#    'indian': 98.23559512112112,
#    'black': 1.4533613743401392,
#    'white': 0.031064176105994053,
#    'middle eastern': 0.05227250824257781,
#    'latino hispanic': 0.22186850123068697},
#   'dominant_race': 'indian'}]

# %%
img_path_baby='baby.jpg'
img_baby=plt.imread('baby.jpg')

# %%
resut_baby=DeepFace.analyze(img_path_baby,actions)
# Out:
# Action: race: 100%|██████████| 4/4 [00:02<00:00,  1.75it/s]

# %%
resut_baby
# Out:
# [{'age': 30,
#   'region': {'x': 231,
#    'y': 80,
#    'w': 253,
#    'h': 253,
#    'left_eye': (393, 184),
#    'right_eye': (338, 216)},
#   'face_confidence': 0.97,
#   'gender': {'Woman': 28.61642837524414, 'Man': 71.38357758522034},
#   'dominant_gender': 'Man',
#   'emotion': {'angry': 1.0793829762755584e-05,
#    'disgust': 2.8076542765540404e-08,
#    'fear': 3.2692545021326286e-05,
#    'happy': 99.87000822246124,
#    'sad': 0.1043803237195506,
#    'surprise': 4.370257818295612e-15,
#    'neutral': 0.025573324888658516},
#   'dominant_emotion': 'happy',
#   'race': {'asian': 74.72099661827087,
#    'indian': 0.04258730332367122,
#    'black': 0.006333110650302842,
#    'white': 24.16730374097824,
#    'middle eastern': 0.18011623760685325,
#    'latino hispanic': 0.8826630190014839},
#   'dominant_race': 'asian'}]
